# %% [markdown]
# # Visualisasi Data Menggunakan Python dan Matplotlib
#
# matplotlib adalah librari Python yang populer untuk menghasilkan plots dan visualisasi data 2D. matplotlib menyediakan fitur untuk dapat secara interaktif (plot) menggambar data, dan melakukan eksplorasi.

# %% [markdown]
# ## Installation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Format Strings in plot function

# %% [markdown]
# Dokumentasi API untuk Format Strings pada matplotlib.pyplot.plot dapat dilihat melalui halaman ini:
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='green',linewidth=5, linestyle='dotted')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='green',linewidth=5, linestyle='dotted')

# %%
plt.plot(x,y,'b+--')

# %%
# Same effect as 'b+' format string
plt.plot(x,y,color='blue',marker='+',linestyle='')

# %% [markdown]
# ### markersize

# %%
plt.plot(x,y,color='blue',marker='+',linestyle='',markersize=20)

# %% [markdown]
# ### alpha property to control transparency of line chart

# %%
plt.plot(x,y,'g<',alpha=0.5) # alpha can be specified on a scale 0 to 1

# %% [markdown]
# ## Axes labels, Legend, Grid

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

# %% [markdown]
# ### Axes labels and chart title

# %%
# set axes labels and chart title
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

# %% [markdown]
# ### Legend

# %% [markdown]
# Dokumentasi API Legend : https://matplotlib.org/api/_as_gen/matplotlib.pyplot.legend.html#matplotlib.pyplot.legend

# %%
# Show legend
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='best')

# %%
# Legend at different location with shadow enabled and fontsize set to large
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='upper right',shadow=True,fontsize='large')

# %% [markdown]
# ### Grid
#
# Dokumentasi API Grid : https://matplotlib.org/api/_as_gen/matplotlib.pyplot.grid.html#matplotlib.pyplot.grid

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='best',shadow=True, fontsize='small')

plt.grid()

# %% [markdown]
# ## Bar Chart

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
plt.bar(company,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
#chhange string to array
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.bar(xpos,revenue, label="Revenue")
plt.legend()

# %% [markdown]
# ### Multiple Bars showing revenue and profit of major US tech companies

# %%
profit=[40,2,34,12]

# %%
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.bar(xpos,revenue, label="Revenue")
plt.bar(xpos,profit, label="Profit")
plt.legend()

# %%
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.bar(xpos-0.2,revenue, width=0.4, label="Revenue")
plt.bar(xpos+0.2,profit, width=0.4,label="Profit")
plt.legend()

# %%
plt.yticks(xpos,company)
plt.title('US Technology Stocks')

plt.barh(xpos,revenue, label="Revenue")
plt.barh(xpos,profit, label="Profit")
plt.legend()

# %% [markdown]
# # Histogram
#
# Histogram adalah gambaran visual dari frekuensi data numerik berdasarkan kelompok yang dibentuk dari rentang nilai yang berurutan (bins). Histogram secara visual menyerupai diagram batang dengan perbedaan dimana setiap batangnya tidak memiliki celah.

# %% [markdown]
# ![gambar1](https://i.ibb.co/Ht0k89G/contoh-kasus.jpg)

# %% [markdown]
# ![gamabr2](https://i.ibb.co/0rD5wD6/contoh-kasus2.jpg)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar) # by default number of bins is set to 10
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### bins parameter

# %%
plt.hist(blood_sugar,bins=13)
# Out:
# (array([3., 2., 2., 0., 0., 0., 2., 0., 0., 1., 1., 0., 2.]),
#  array([ 77.        ,  82.61538462,  88.23076923,  93.84615385,
#          99.46153846, 105.07692308, 110.69230769, 116.30769231,
#         121.92307692, 127.53846154, 133.15384615, 138.76923077,
#         144.38461538, 150.        ]),
#  <a list of 13 Patch objects>)

# %% [markdown]
# ### Histogram showing normal, pre-diabetic and diabetic patients distribution
# - 80-100: Normal
# - 100-125: Pre-diabetic
# - 80-100: Diabetic

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color='g')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 3 Patch objects>)

# %% [markdown]
# ### Mutiple data samples in a histogram

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['men','women'])
plt.legend()

# %% [markdown]
# ### histtype=step

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype='step')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 1 Patch objects>)

# %% [markdown]
# ### horizontal orientation

# %%
plt.xlabel("Number Of Patients")
plt.ylabel("Sugar Level")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, orientation='horizontal')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 3 Patch objects>)

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# ![gambar3](https://i.ibb.co/NFSNBKt/contoh-kasus3.jpg)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### Draw pie chart to track down home expenses

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]
plt.pie(exp_vals,labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1976bc8b588>,
#   <matplotlib.patches.Wedge at 0x1976bc8bd88>,
#   <matplotlib.patches.Wedge at 0x1976bc91708>,
#   <matplotlib.patches.Wedge at 0x1976bc96108>,
#   <matplotlib.patches.Wedge at 0x1976bc96f08>],
#  [Text(0.09328656407206024, 1.0960372333838069, 'Home Rent'),
#   Text(-0.9822184890776084, -0.4952240298229684, 'Food'),
#   Text(-0.16284704617934698, -1.0878790555712807, 'Phone/Internet Bill'),
#   Text(0.6256100334857941, -0.9047718419590123, 'Car '),
#   Text(1.0615045230766318, -0.28845822485734873, 'Other Utilities')])

# %% [markdown]
# ### Draw pie chart as perfect circle

# %%
plt.pie(exp_vals,labels=exp_labels, shadow=True)
plt.axis("equal")
plt.show()

# %% [markdown]
# ### Show percentages for every pie. Specify radius to increase chart size

# %%
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5)
plt.show()

# %% [markdown]
# ### Explode

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2])
plt.show()

# %% [markdown]
# ### counterclock and angle properties

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2],counterclock=True, startangle=45)
plt.show()

# %% [markdown]
# ## Saving chart to a file using savefig

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=2, autopct='%0.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig("D:/piechart.jpg", bbox_inches="tight", pad_inches=1, transparent=True)
